# %%
sub-0001_0.04_1.75_0.005_FCD.txt.npy
# Out:
#   Cell In[3], line 1
#     sub-0001_0.04_1.75_0.005_FCD.txt.npy
#                             ^
# SyntaxError: invalid decimal literal

# %%
import numpy as np

data = np.load('sub-0001_0.04_1.75_0.005_FCD.txt.npy')
print(data)
# Out:
# [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# ...

# %%
data = np.load('sub-0001_0.04_1.75_0.005_FCD.txt.npy')
print(data)
# Out:
# [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# ...
