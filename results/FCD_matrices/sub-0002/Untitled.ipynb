# %%
sub-0002_0.02_1.65_0.005_FCD.txt.npy
# Out:
#   Cell In[1], line 1
#     sub-0002_0.02_1.65_0.005_FCD.txt.npy
#                             ^
# SyntaxError: invalid decimal literal

# %%
import numpy as np

data = np.load('sub-0002_0.02_1.95_0.005_FCD.txt.npy')
print(data)
# Out:
# [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# ...
